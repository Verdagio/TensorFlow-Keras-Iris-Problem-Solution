# %% [markdown]
# # Iris Data set Tensorflow

# %%
import csv
import numpy as np
import keras as kr
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load the iris dataset into an array

# %%
#load the Iris dataset
iris = list(csv.reader(open("./data/IRIS.csv")))[1:]

# 4 inputs sepal length & width, petal length & width
inputs = np.array(iris)[:,:4].astype(np.float)

# outputs are initially strings , setosa, versicolor, virginica
outputs = np.array(iris)[:,4]

#convert the out strings to ints
outputs_vals, outputs_inds = np.unique(outputs, return_inverse=True)

# %% [markdown]
# ### Encode and split into test & train subsets

# %%
# endocde the category integers as binary categorial vairables.
outputs_cats = kr.utils.to_categorical(outputs_inds)

# split the input & output data sets into training and test subsets
inds = np.random.permutation(len(inputs))

train_inds, test_inds = np.array_split(inds, 2)

inputs_train, outputs_train = inputs[train_inds], outputs_cats[train_inds]
inputs_test, outputs_test = inputs[test_inds], outputs_cats[test_inds]

# %% [markdown]
# ### Create a neural network, add layers & nodes

# %%
#creats a neral network
model = kr.models.Sequential()

# add an initial layer with 4 inputs nodes, and a hidden layer with 16 nodes
model.add(kr.layers.Dense(16, input_shape=(4,)))

#appy the signoid activation function to that layer
model.add(kr.layers.Activation("sigmoid"))

#add another layer connected to the layet with 16 nodes containing 3 output nodes
model.add(kr.layers.Dense(3))

#use the softmax activation function there
model.add(kr.layers.Activation("softmax"))

# %% [markdown]
# ### Configure the model for training, fit using training data, & evaluate using the test data

# %%
# configure the model for training
# uses the adam optimizer and categorialcross entropy as the loss function
# add in some extra metrics, accuracy being the only one.
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

#fit the model using our training data
model.fit(inputs_train, outputs_train, epochs=100, batch_size=1, verbose=1)
#evaluate the model using the test data set
loss, accuracy = model.evaluate(inputs_test, outputs_test, verbose=1)


print("\n\nloss: %6.4f\nAccuracy: %6.4f"% (loss, accuracy))
# Out:
# Epoch 1/100
# 75/75 [==============================] - 1s 17ms/step - loss: 1.2861 - acc: 0.2667
# Epoch 2/100
# 75/75 [==============================] - 0s 4ms/step - loss: 1.1192 - acc: 0.3867
# Epoch 3/100
# 75/75 [==============================] - 0s 4ms/step - loss: 1.0393 - acc: 0.6800
# Epoch 4/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.9813 - acc: 0.6267
# Epoch 5/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.9252 - acc: 0.6800
# Epoch 6/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.8777 - acc: 0.6800
# Epoch 7/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.8261 - acc: 0.6800
# Epoch 8/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.7780 - acc: 0.6800
# Epoch 9/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.7365 - acc: 0.6800
# Epoch 10/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.6989 - acc: 0.6933
# Epoch 11/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.6703 - acc: 0.6800
# Epoch 12/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.6446 - acc: 0.6800
# Epoch 13/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.6198 - acc: 0.8267
# Epoch 14/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.5993 - acc: 0.7333
# Epoch 15/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.5801 - acc: 0.7200
# Epoch 16/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.5680 - acc: 0.6800
# Epoch 17/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.5574 - acc: 0.7200
# Epoch 18/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.5412 - acc: 0.7867
# Epoch 19/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.5267 - acc: 0.8133
# Epoch 20/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.5190 - acc: 0.8933
# Epoch 21/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.5062 - acc: 0.7200
# Epoch 22/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.4915 - acc: 0.9200
# Epoch 23/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.4827 - acc: 0.8133
# Epoch 24/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.4748 - acc: 0.8667
# Epoch 25/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.4669 - acc: 0.9467
# Epoch 26/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.4605 - acc: 0.9067
# Epoch 27/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.4512 - acc: 0.8133
# Epoch 28/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.4414 - acc: 0.9067
# Epoch 29/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.4330 - acc: 0.9200
# Epoch 30/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.4282 - acc: 0.9467
# Epoch 31/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.4203 - acc: 0.9733
# Epoch 32/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.4117 - acc: 0.9200
# Epoch 33/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.4049 - acc: 0.9733
# Epoch 34/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.3987 - acc: 0.9733
# Epoch 35/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.3948 - acc: 0.9600
# Epoch 36/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.3972 - acc: 0.9200
# Epoch 37/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3827 - acc: 0.9200
# Epoch 38/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3757 - acc: 0.9733
# Epoch 39/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3687 - acc: 0.9600
# Epoch 40/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3634 - acc: 0.9733
# Epoch 41/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3568 - acc: 0.9200
# Epoch 42/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3525 - acc: 0.9600
# Epoch 43/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3468 - acc: 0.9600
# Epoch 44/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3389 - acc: 0.9600
# Epoch 45/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3349 - acc: 0.9733
# Epoch 46/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3253 - acc: 0.9733
# Epoch 47/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.3259 - acc: 0.9733
# Epoch 48/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.3198 - acc: 0.9733
# Epoch 49/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3164 - acc: 0.9733
# Epoch 50/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3044 - acc: 0.9733
# Epoch 51/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2996 - acc: 0.9733
# Epoch 52/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.2990 - acc: 0.9733
# Epoch 53/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2926 - acc: 0.9733
# Epoch 54/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2841 - acc: 0.9733
# Epoch 55/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2801 - acc: 0.9733
# Epoch 56/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2762 - acc: 0.9733
# Epoch 57/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2742 - acc: 0.9733
# Epoch 58/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2692 - acc: 0.9600
# Epoch 59/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2638 - acc: 0.9733
# Epoch 60/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2598 - acc: 0.9733
# Epoch 61/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2538 - acc: 0.9733
# Epoch 62/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2507 - acc: 0.9733
# Epoch 63/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2490 - acc: 0.9733
# Epoch 64/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2405 - acc: 0.9733
# Epoch 65/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2377 - acc: 0.9733
# Epoch 66/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2358 - acc: 0.9733
# Epoch 67/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2327 - acc: 0.9733
# Epoch 68/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2277 - acc: 0.9733
# Epoch 69/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2238 - acc: 0.9733
# Epoch 70/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2215 - acc: 0.9733
# Epoch 71/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2190 - acc: 0.9733
# Epoch 72/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2141 - acc: 0.9733
# Epoch 73/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2095 - acc: 0.9733
# Epoch 74/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2068 - acc: 0.9733
# Epoch 75/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2054 - acc: 0.9733
# Epoch 76/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2050 - acc: 0.9600
# Epoch 77/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1987 - acc: 0.9600
# Epoch 78/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1970 - acc: 0.9733
# Epoch 79/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1961 - acc: 0.9600
# Epoch 80/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1911 - acc: 0.9733
# Epoch 81/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1866 - acc: 0.9733
# Epoch 82/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1837 - acc: 0.9733
# Epoch 83/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1829 - acc: 0.9733
# Epoch 84/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1799 - acc: 0.9600
# Epoch 85/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1787 - acc: 0.9600
# Epoch 86/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1792 - acc: 0.9733
# Epoch 87/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1770 - acc: 0.9467
# Epoch 88/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1749 - acc: 0.9600
# Epoch 89/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1682 - acc: 0.9733
# Epoch 90/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1754 - acc: 0.9733
# Epoch 91/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1654 - acc: 0.9733
# Epoch 92/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1640 - acc: 0.9600
# Epoch 93/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1613 - acc: 0.9600
# Epoch 94/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1570 - acc: 0.9600
# Epoch 95/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1575 - acc: 0.9733
# Epoch 96/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1526 - acc: 0.9867
# Epoch 97/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1567 - acc: 0.9733
# Epoch 98/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1534 - acc: 0.9733
# Epoch 99/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1503 - acc: 0.9733
# Epoch 100/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1492 - acc: 0.9733
# 75/75 [==============================] - 0s 580us/step
#
#
# loss: 0.1190
# Accuracy: 0.9600

# %%
# Predict the class of a single flower.
prediction = np.around(model.predict(np.expand_dims(inputs_test[0], axis=0))).astype(np.int)[0]
print("Actual: %s\tEstimated: %s" % (outputs_test[0].astype(np.int), prediction))
print("That means it's a %s" % outputs_vals[prediction.astype(np.bool)][0])

# Save the model to a file for later use.
model.save("./data/iris_nn.h5")
# Load the model again with: model = load_model("./data/iris_nn.h5")
# Out:
# Actual: [1 0 0]	Estimated: [1 0 0]
# That means it's a setosa

# %% [markdown]
# # End
