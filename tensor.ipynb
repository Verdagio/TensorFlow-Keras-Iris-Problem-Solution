# %% [markdown]
# # Iris Data set Tensorflow
#
# First we need to import our dependencies

# %%
import csv
import numpy as np
import keras as kr
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load the iris dataset into an array

# %%
#load the Iris dataset
iris = list(csv.reader(open("IRIS.csv")))[1:]

# 4 inputs sepal length & width, petal length & width
inputs = np.array(iris)[:,:4].astype(np.float)

# outputs are initially strings , setosa, versicolor, virginica
outputs = np.array(iris)[:,4]

#convert the out strings to ints
outputs_vals, outputs_inds = np.unique(outputs, return_inverse=True)

# %% [markdown]
# ### Encode and split into test & train subsets

# %%
# endocde the category integers as binary categorial vairables.
outputs_cats = kr.utils.to_categorical(outputs_inds)

# split the input & output data sets into training and test subsets
inds = np.random.permutation(len(inputs))

train_inds, test_inds = np.array_split(inds, 2)

inputs_train, outputs_train = inputs[train_inds], outputs_cats[train_inds]
inputs_test, outputs_test = inputs[test_inds], outputs_cats[test_inds]

# %% [markdown]
# ### Create a neural network, add layers & nodes

# %%
#creats a neral network
model = kr.models.Sequential()

# add an initial layer with 4 inputs nodes, and a hidden layer with 16 nodes
model.add(kr.layers.Dense(16, input_shape=(4,)))

#appy the signoid activation function to that layer
model.add(kr.layers.Activation("sigmoid"))

#add another layer connected to the layet with 16 nodes containing 3 output nodes
model.add(kr.layers.Dense(3))

#use the softmax activation function there
model.add(kr.layers.Activation("softmax"))

# %% [markdown]
# ### Configure the model for training, fit using training data, & evaluate using the test data

# %%
# configure the model for training
# uses the adam optimizer and categorialcross entropy as the loss function
# add in some extra metrics, accuracy being the only one.
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

#fit the model using our training data
model.fit(inputs_train, outputs_train, epochs=100, batch_size=1, verbose=1)
#evaluate the model using the test data set
loss, accuracy = model.evaluate(inputs_test, outputs_test, verbose=1)


print("\n\nloss: %6.4f\nAccuracy: %6.4f"% (loss, accuracy))
# Out:
# Epoch 1/100
# 75/75 [==============================] - 1s 12ms/step - loss: 1.1687 - acc: 0.3333
# Epoch 2/100
# 75/75 [==============================] - 0s 4ms/step - loss: 1.0133 - acc: 0.5067
# Epoch 3/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.9354 - acc: 0.6667
# Epoch 4/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.8801 - acc: 0.6667
# Epoch 5/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.8287 - acc: 0.6800
# Epoch 6/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.7862 - acc: 0.6933
# Epoch 7/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.7430 - acc: 0.7467
# Epoch 8/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.7076 - acc: 0.8000
# Epoch 9/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.6783 - acc: 0.8667
# Epoch 10/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.6465 - acc: 0.8133
# Epoch 11/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.6221 - acc: 0.8267
# Epoch 12/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.6007 - acc: 0.8267
# Epoch 13/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.5823 - acc: 0.8133
# Epoch 14/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.5614 - acc: 0.8800
# Epoch 15/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.5441 - acc: 0.8533
# Epoch 16/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5317 - acc: 0.9467
# Epoch 17/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.5177 - acc: 0.9333
# Epoch 18/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.4999 - acc: 0.9067
# Epoch 19/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.4907 - acc: 0.9467
# Epoch 20/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.4791 - acc: 0.9733
# Epoch 21/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.4683 - acc: 0.8933
# Epoch 22/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.4607 - acc: 0.9333
# Epoch 23/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.4531 - acc: 0.9733
# Epoch 24/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.4460 - acc: 0.9200
# Epoch 25/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.4371 - acc: 0.9067
# Epoch 26/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.4283 - acc: 0.9733
# Epoch 27/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.4188 - acc: 0.9600
# Epoch 28/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.4142 - acc: 0.9467
# Epoch 29/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.4054 - acc: 0.9600
# Epoch 30/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3978 - acc: 0.9600
# Epoch 31/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3936 - acc: 0.9733
# Epoch 32/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3846 - acc: 0.9600
# Epoch 33/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3792 - acc: 0.9600
# Epoch 34/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3768 - acc: 0.9600
# Epoch 35/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3694 - acc: 0.9733
# Epoch 36/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3629 - acc: 0.9600
# Epoch 37/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.3552 - acc: 0.9867
# Epoch 38/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3495 - acc: 0.9600
# Epoch 39/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3422 - acc: 0.9600
# Epoch 40/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3414 - acc: 0.9600
# Epoch 41/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3312 - acc: 0.9600
# Epoch 42/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3267 - acc: 0.9733
# Epoch 43/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3201 - acc: 0.9600
# Epoch 44/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3172 - acc: 0.9600
# Epoch 45/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3093 - acc: 0.9600
# Epoch 46/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3055 - acc: 0.9600
# Epoch 47/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3049 - acc: 0.9600
# Epoch 48/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2960 - acc: 0.9467
# Epoch 49/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.2902 - acc: 0.9733
# Epoch 50/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.2850 - acc: 0.9733
# Epoch 51/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.2791 - acc: 0.9867
# Epoch 52/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2754 - acc: 0.9600
# Epoch 53/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2701 - acc: 0.9733
# Epoch 54/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2646 - acc: 0.9600
# Epoch 55/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2605 - acc: 0.9733
# Epoch 56/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2559 - acc: 0.9733
# Epoch 57/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2527 - acc: 0.9600
# Epoch 58/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2498 - acc: 0.9600
# Epoch 59/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2465 - acc: 0.9600
# Epoch 60/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2421 - acc: 0.9600
# Epoch 61/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2380 - acc: 0.9733
# Epoch 62/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2343 - acc: 0.9600
# Epoch 63/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2286 - acc: 0.9733
# Epoch 64/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2291 - acc: 0.9600
# Epoch 65/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2209 - acc: 0.9733
# Epoch 66/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2179 - acc: 0.9600
# Epoch 67/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.2141 - acc: 0.9733
# Epoch 68/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.2129 - acc: 0.9733
# Epoch 69/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.2085 - acc: 0.9733A: 0s - loss: 0.1875 - acc: 1
# Epoch 70/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.2087 - acc: 0.9733
# Epoch 71/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2070 - acc: 0.9733
# Epoch 72/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2022 - acc: 0.9467- ETA: 0s - loss: 0.2268 - acc: 0.857
# Epoch 73/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.2015 - acc: 0.9600
# Epoch 74/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1968 - acc: 0.9600
# Epoch 75/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1937 - acc: 0.9600
# Epoch 76/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1909 - acc: 0.9733
# Epoch 77/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1855 - acc: 0.9867
# Epoch 78/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1847 - acc: 0.9733
# Epoch 79/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1798 - acc: 0.9733
# Epoch 80/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1799 - acc: 0.9600
# Epoch 81/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1813 - acc: 0.9733
# Epoch 82/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1747 - acc: 0.9733
# Epoch 83/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1742 - acc: 0.9733
# Epoch 84/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1721 - acc: 0.9733
# Epoch 85/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1736 - acc: 0.9733
# Epoch 86/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1670 - acc: 0.9733
# Epoch 87/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1636 - acc: 0.9867
# Epoch 88/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1624 - acc: 0.9733
# Epoch 89/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1645 - acc: 0.9467
# Epoch 90/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1579 - acc: 0.9867
# Epoch 91/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1580 - acc: 0.9867
# Epoch 92/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1560 - acc: 0.9733
# Epoch 93/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1536 - acc: 0.9867
# Epoch 94/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1537 - acc: 0.9600
# Epoch 95/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1521 - acc: 0.9867
# Epoch 96/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1495 - acc: 0.9867A: 0s - loss: 0.1499 - acc: 1.
# Epoch 97/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1502 - acc: 0.9733
# Epoch 98/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1487 - acc: 0.9867A: 0s - loss: 0.1434 - acc: 1.000 - ETA: 0s - loss: 0.2006 - acc: 0.
# Epoch 99/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1481 - acc: 0.9600
# Epoch 100/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1449 - acc: 0.9733
# 75/75 [==============================] - 0s 694us/step
#
#
# loss: 0.1206
# Accuracy: 0.9600

# %%
# Predict the class of a single flower.
prediction = np.around(model.predict(np.expand_dims(inputs_test[0], axis=0))).astype(np.int)[0]
print("Actual: %s\tEstimated: %s" % (outputs_test[0].astype(np.int), prediction))
print("That means it's a %s" % outputs_vals[prediction.astype(np.bool)][0])

# Save the model to a file for later use.
model.save("iris_nn.h5")
# Load the model again with: model = load_model("iris_nn.h5")
# Out:
# Actual: [0 0 1]	Estimated: [0 0 1]
# That means it's a virginica
