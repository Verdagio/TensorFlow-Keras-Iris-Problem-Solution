# %% [markdown]
# # Iris Data set Tensorflow
#
# First we need to import our dependencies

# %%
import csv
import numpy as np
import keras as kr

# %% [markdown]
# ### Load the iris dataset into an array

# %%
#load the Iris dataset
iris = list(csv.reader(open("IRIS.csv")))[1:]

# 4 inputs sepal length & width, petal length & width
inputs = np.array(iris)[:,:4].astype(np.float)

# outputs are initially strings , setosa, versicolor, virginica
outputs = np.array(iris)[:,4]

#convert the out strings to ints
outputs_vals, outputs_inds = np.unique(outputs, return_inverse=True)

# %% [markdown]
# ### Encode and split into test & train subsets

# %%
# endocde the category integers as binary categorial vairables.
outputs_cats = kr.utils.to_categorical(outputs_inds)

# split the input & output data sets into training and test subsets
inds = np.random.permutation(len(inputs))

train_inds, test_inds = np.array_split(inds, 2)

inputs_train, outputs_train = inputs[train_inds], outputs_cats[train_inds]
inputs_test, outputs_test = inputs[test_inds], outputs_cats[test_inds]

# %% [markdown]
# ### Create a neural network, add layers & nodes

# %%
#creats a neral network
model = kr.models.Sequential()

# add an initial layer with 4 inputs nodes, and a hidden layer with 16 nodes
model.add(kr.layers.Dense(16, input_shape=(4,)))

#appy the signoid activation function to that layer
model.add(kr.layers.Activation("sigmoid"))

#add another layer connected to the layet with 16 nodes containing 3 output nodes
model.add(kr.layers.Dense(3))

#use the softmax activation function there
model.add(kr.layers.Activation("softmax"))

# %% [markdown]
# ### Configure the model for training, fit using training data, & evaluate using the test data

# %%
# configure the model for training
# uses the adam optimizer and categorialcross entropy as the loss function
# add in some extra metrics, accuracy being the only one.
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

#fit the model using our training data
model.fit(inputs_train, outputs_train, epochs=100, batch_size=1, verbose=1)
#evaluate the model using the test data set
loss, accuracy = model.evaluate(inputs_test, outputs_test, verbose=1)


print("\n\nloss: %6.4f\nAccuracy: %6.4f"% (loss, accuracy))
# Out:
# Epoch 1/100
# 75/75 [==============================] - 1s 14ms/step - loss: 0.1512 - acc: 0.9733
# Epoch 2/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1463 - acc: 0.9733
# Epoch 3/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1427 - acc: 0.9733
# Epoch 4/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1435 - acc: 0.9733
# Epoch 5/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1415 - acc: 0.9600
# Epoch 6/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1392 - acc: 0.9733
# Epoch 7/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1380 - acc: 0.9733
# Epoch 8/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1373 - acc: 0.9600
# Epoch 9/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1369 - acc: 0.9600
# Epoch 10/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1369 - acc: 0.9733
# Epoch 11/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1341 - acc: 0.9733
# Epoch 12/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1354 - acc: 0.9467
# Epoch 13/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1351 - acc: 0.9733
# Epoch 14/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1296 - acc: 0.9600
# Epoch 15/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1296 - acc: 0.9600
# Epoch 16/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1286 - acc: 0.9467
# Epoch 17/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1281 - acc: 0.9467
# Epoch 18/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1235 - acc: 0.9733
# Epoch 19/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1247 - acc: 0.9600
# Epoch 20/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1227 - acc: 0.9600
# Epoch 21/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1198 - acc: 0.9733
# Epoch 22/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1203 - acc: 0.9600
# Epoch 23/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1202 - acc: 0.9733
# Epoch 24/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1181 - acc: 0.9733
# Epoch 25/100
# 75/75 [==============================] - ETA: 0s - loss: 0.1120 - acc: 0.969 - 0s 4ms/step - loss: 0.1162 - acc: 0.9733
# Epoch 26/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1188 - acc: 0.9600
# Epoch 27/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1174 - acc: 0.9600
# Epoch 28/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1154 - acc: 0.9600
# Epoch 29/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1159 - acc: 0.9600
# Epoch 30/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1151 - acc: 0.9733
# Epoch 31/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1130 - acc: 0.9600
# Epoch 32/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1152 - acc: 0.9467
# Epoch 33/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1137 - acc: 0.9733
# Epoch 34/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1099 - acc: 0.9733
# Epoch 35/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1156 - acc: 0.9733
# Epoch 36/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1116 - acc: 0.9600
# Epoch 37/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1074 - acc: 0.9600
# Epoch 38/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1144 - acc: 0.9600
# Epoch 39/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1080 - acc: 0.9600
# Epoch 40/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1108 - acc: 0.9733
# Epoch 41/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1066 - acc: 0.9600
# Epoch 42/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1055 - acc: 0.9733
# Epoch 43/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1081 - acc: 0.9600
# Epoch 44/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1033 - acc: 0.9733
# Epoch 45/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1065 - acc: 0.9600
# Epoch 46/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1126 - acc: 0.9467
# Epoch 47/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1045 - acc: 0.9733
# Epoch 48/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1020 - acc: 0.9733
# Epoch 49/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1030 - acc: 0.9733
# Epoch 50/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1023 - acc: 0.9600
# Epoch 51/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1008 - acc: 0.9733
# Epoch 52/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0997 - acc: 0.9733
# Epoch 53/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1044 - acc: 0.9733
# Epoch 54/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0984 - acc: 0.9600
# Epoch 55/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0987 - acc: 0.9733
# Epoch 56/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1012 - acc: 0.9600
# Epoch 57/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1008 - acc: 0.9600
# Epoch 58/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0985 - acc: 0.9733
# Epoch 59/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1039 - acc: 0.9733
# Epoch 60/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1030 - acc: 0.9600
# Epoch 61/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0969 - acc: 0.9600
# Epoch 62/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0978 - acc: 0.9733
# Epoch 63/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0971 - acc: 0.9733
# Epoch 64/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1026 - acc: 0.9600
# Epoch 65/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0973 - acc: 0.9600
# Epoch 66/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1025 - acc: 0.9600
# Epoch 67/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0953 - acc: 0.9733
# Epoch 68/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0935 - acc: 0.9600
# Epoch 69/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0980 - acc: 0.9600
# Epoch 70/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0956 - acc: 0.9733
# Epoch 71/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0977 - acc: 0.9600
# Epoch 72/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0960 - acc: 0.9600
# Epoch 73/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0933 - acc: 0.9733
# Epoch 74/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0950 - acc: 0.9600
# Epoch 75/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0920 - acc: 0.9733
# Epoch 76/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0989 - acc: 0.9600
# Epoch 77/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0952 - acc: 0.9467
# Epoch 78/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0930 - acc: 0.9733
# Epoch 79/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0923 - acc: 0.9600
# Epoch 80/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0923 - acc: 0.9600
# Epoch 81/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0913 - acc: 0.9733
# Epoch 82/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0903 - acc: 0.9600
# Epoch 83/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0913 - acc: 0.9600
# Epoch 84/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0929 - acc: 0.9733
# Epoch 85/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0913 - acc: 0.9600
# Epoch 86/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0911 - acc: 0.9733
# Epoch 87/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0884 - acc: 0.9733
# Epoch 88/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0964 - acc: 0.9733
# Epoch 89/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0920 - acc: 0.9600
# Epoch 90/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0952 - acc: 0.9733
# Epoch 91/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0909 - acc: 0.9733
# Epoch 92/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0887 - acc: 0.9600
# Epoch 93/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0880 - acc: 0.9733
# Epoch 94/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0924 - acc: 0.9733
# Epoch 95/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0878 - acc: 0.9733
# Epoch 96/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0906 - acc: 0.9600
# Epoch 97/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0885 - acc: 0.9733
# Epoch 98/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0885 - acc: 0.9600
# Epoch 99/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0917 - acc: 0.9600
# Epoch 100/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0857 - acc: 0.9733
# 75/75 [==============================] - 0s 1ms/step
#
#
# loss: 0.0596
# Accuracy: 1.0000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-fd4ed97e28e7> in <module>()
#      13
#      14 prediction = np.around(model.predict(np.expand_dims(inputs_test[0], axis=0))).astype(np.int)[0]
# ---> 15 print("actual: %4.f\testimated: %s"  % (outputs_test[0].astype(np.int), prediction))
#      16 print("that means it is a %s" % outputs_vals[prediction.astype(np.bool)][0])
#      17
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
# Predict the class of a single flower.
prediction = np.around(model.predict(np.expand_dims(inputs_test[0], axis=0))).astype(np.int)[0]
print("Actual: %s\tEstimated: %s" % (outputs_test[0].astype(np.int), prediction))
print("That means it's a %s" % outputs_vals[prediction.astype(np.bool)][0])

# Save the model to a file for later use.
model.save("iris_nn.h5")
# Load the model again with: model = load_model("iris_nn.h5")
